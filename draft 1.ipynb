# %% [markdown]
# # <span style = 'color:crimson'> Lead Score Case Study
# -----------------------------------------------------------

# %% [markdown]
# ##### <pre> <span style = 'color:salmon'> 🪄 This assignment is a Group Assignment and the contributors are <span style = 'color:black'>**Sudeshna Mahapatra** <span style = 'color:salmon'> and  <span style = 'color:black'> **Dip Gosh**

# %% [markdown]
# ## 🪴<span style = 'color:violet'>_**Problem Statement**_
# -----------------------------------------------------------------
#
#  An education company named X Education sells online courses to industry professionals.On any given day, many professionals who are interested in the courses land on their website and browse for courses.
#
#
#
# The company markets its courses on several websites and search engines like Google. Once these people land on the website, they might browse the courses or fill up a form for the course or watch some videos. When these people fill up a form providing their email address or phone number, they are classified to be a lead. Moreover, the company also gets leads through past referrals. Once these leads are acquired, employees from the sales team start making calls, writing emails, etc. Through this process, some of the leads get converted while most do not. The typical lead conversion rate at X education is around 30%.
#
#
#
# Now, although X Education gets a lot of leads, its lead conversion rate is very poor. For example, if, say, they acquire 100 leads in a day, only about 30 of them are converted. To make this process more efficient, the company wishes to identify the most potential leads, also known as ‘Hot Leads’. If they successfully identify this set of leads, the lead conversion rate should go up as the sales team will now be focusing more on communicating with the potential leads rather than making calls to everyone. A typical lead conversion process can be represented using the following funnel:

# %% [markdown]
# ![XNote_201901081613670.jpg](attachment:XNote_201901081613670.jpg)

# %% [markdown]
#                                        Lead Conversion Process - Demonstrated as a funnel

# %% [markdown]
# As you can see, there are a lot of leads generated in the initial stage (top) but only a few of them come out as paying customers from the bottom. In the middle stage, you need to nurture the potential leads well (i.e. educating the leads about the product, constantly communicating etc. ) in order to get a higher lead conversion.
#
#
#
# X Education has appointed you to help them select the most promising leads, i.e. the leads that are most likely to convert into paying customers. The company requires you to build a model wherein you need to assign a lead score to each of the leads such that the customers with higher lead score have a higher conversion chance and the customers with lower lead score have a lower conversion chance. The CEO, in particular, has given a ballpark of the target lead conversion rate to be around 80%.

# %% [markdown]
# ## 🪴<span style = 'color:blue'>_**Data**_
# -----------------------------------------------------------------
#
# You have been provided with a leads dataset from the past with around 9000 data points. This dataset consists of various attributes such as Lead Source, Total Time Spent on Website, Total Visits, Last Activity, etc. which may or may not be useful in ultimately deciding whether a lead will be converted or not. The target variable, in this case, is the column ‘Converted’ which tells whether a past lead was converted or not wherein 1 means it was converted and 0 means it wasn’t converted. You can learn more about the dataset from the data dictionary provided in the zip folder at the end of the page. Another thing that you also need to check out for are the levels present in the categorical variables. Many of the categorical variables have a level called 'Select' which needs to be handled because it is as good as a null value (think why?).

# %% [markdown]
# ## 🪴<span style = 'color:brown'>_**Goals of the Case Study:**_
# --------------------------------------------
#
# There are quite a few goals for this case study.
#
#     1. Build a logistic regression model to assign a lead score between 0 and 100 to each of the leads which can be used by the company to target potential leads. A higher score would mean that the lead is hot, i.e. is most likely to convert whereas a lower score would mean that the lead is cold and will mostly not get converted.
#
#     2. There are some more problems presented by the company which your model should be able to adjust to if the company's requirement changes in the future so you will need to handle these as well. These problems are provided in a separate doc file. Please fill it based on the logistic regression model you got in the first step. Also, make sure you include this in your final PPT where you'll make recommendations.
#
#
# ## 🪴<span style = 'color:orange'>_**Results Expected:**_
# ---------------------------------------------
#
#     1. A well-commented Jupyter note with at least the logistic regression model, the conversion predictions and evaluation metrics.
#
#     2. The word document filled with solutions to all the problems.
#
#     3. The overall approach of the analysis in a presentation
#         - Mention the problem statement and the analysis approach briefly
#         - Explain the results in business terms
#         - Include visualisations and summarise the most important results in the presentation
#
#     4. A brief summary report in 500 words explaining how you proceeded with the assignment and the learnings that you gathered.
#
#
# ## 🪴<span style = 'color:coral'>_**You need to submit the following four components:**_
# -----------------------------------------------------------------
#
#     - **Python commented file:** Should include detailed comments and should not contain unnecessary pieces of code.
#
#     - **Word File:** Answer all the questions asked by the company in the word document provided.
#
#     - **Presentation:**  Make a presentation to present your analysis to the chief data scientist of your company (and thus you should include both technical and business aspects). The presentation should be concise, clear, and to the point. Submit the presentation after converting it into PDF format.
#
#     - **PDF File:** Write the summary report in a word file and submit it as a PDF.
#
#
# ## 🪴<span style = 'color:orchid'>_**Downloads:**_
# -----------------------------------------------------------------
#
# All the files required for the case study are given in the following zip file.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ✍🏻<span style = 'color:darkslateblue'>_**Step-1: Reading and Understanding Data**_

# %% [markdown]
# 🅰️ <span style = 'color:darkgreen'>_**Importing Necessary library modules**_

# %% [markdown]
# 🎗️<span style = 'color:salmon'>_In this step the <span style = 'color:orangered'>**important library modules** <span style = 'color:salmon'>which are required <span style = 'color:lime'>**to read dataset** <span style = 'color:salmon'>, <span style = 'color:teal'>**visualise** <span style = 'color:salmon'>them along with that **statistical model**_ building libraries are imported. For reading the <span style = 'color:red'>dataset <span style = 'color:salmon'>, <span style = 'color:indianred'>**pandas** <span style = 'color:salmon'>library module is being used. For <span style = 'color:red'>visualisation <span style = 'color:salmon'>both <span style = 'color:orangered'>**seaborn** <span style = 'color:salmon'>and <span style = 'color:orangered'>**matplotlib** library is being used._For <span style = 'color:red'>model building and evaluation <span style = 'color:orangered'>**statsmodels** <span style = 'color:salmon'>library is being used._

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.stats.outliers_influence import variance_inflation_factor

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# 🅱️ <span style = 'color:darkgreen'>_**Understanding the structure of the data**_

# %% [markdown]
# 📅<span style = 'color:sienna'>_**Data Sourcing**_

# %% [markdown]
# Since the elements which are required to perform the data analysis are already given along with the problem statement so there is no need to search for it elsewhere.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <span style = 'color:darkslateblue'>_**1️⃣ Reading the dataset/Importing Data**_

# %% [markdown]
# 🎗️<span style = 'color:indigo'>_In this step the <span style = 'color:tomato'>**datasets** <span style = 'color:indigo'>given in the problem statement are imported. Here only the <span style = 'color:orchid'>Leads Dataset <span style = 'color:indigo'>is loaded as it is required for the analysis. However the <span style = 'color:orchid'> Leads Data Dictionary <span style = 'color:indigo'>is just used for reference as it is the data dictionary._

# %%
Leads_data_df = pd.read_csv("Leads.csv")

# %%
Leads_data_df.head()
# Out:
#                             Prospect ID  Lead Number              Lead Origin  \
# 0  7927b2df-8bba-4d29-b9a2-b6e0beafe620       660737                      API
# 1  2a272436-5132-4136-86fa-dcc88c88f482       660728                      API
# 2  8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727  Landing Page Submission
# 3  0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719  Landing Page Submission
# 4  3256f628-e534-4826-9d63-4a8b88782852       660681  Landing Page Submission
#
#       Lead Source Do Not Email Do Not Call  Converted  TotalVisits  \
# 0      Olark Chat           No          No          0          0.0
# 1  Organic Search           No          No          0          5.0
# 2  Direct Traffic           No          No          1          2.0
# 3  Direct Traffic           No          No          0          1.0
# 4          Google           No          No          1          2.0
#
#    Total Time Spent on Website  Page Views Per Visit  ...  \
# ...

# %% [markdown]
# <span style = 'color:darkslateblue'>_**2️⃣ Sanity checks for the loaded Data**_

# %% [markdown]
# 🎗️<span style = 'color:indigo'>_In this step <span style = 'color:tomato'>**Sanity checks** <span style = 'color:indigo'>are performed to check for the validity of the given data._

# %%
#Checking the first 5 rows of the dataframe

# %%
Leads_data_df.head()
# Out:
#                             Prospect ID  Lead Number              Lead Origin  \
# 0  7927b2df-8bba-4d29-b9a2-b6e0beafe620       660737                      API
# 1  2a272436-5132-4136-86fa-dcc88c88f482       660728                      API
# 2  8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727  Landing Page Submission
# 3  0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719  Landing Page Submission
# 4  3256f628-e534-4826-9d63-4a8b88782852       660681  Landing Page Submission
#
#       Lead Source Do Not Email Do Not Call  Converted  TotalVisits  \
# 0      Olark Chat           No          No          0          0.0
# 1  Organic Search           No          No          0          5.0
# 2  Direct Traffic           No          No          1          2.0
# 3  Direct Traffic           No          No          0          1.0
# 4          Google           No          No          1          2.0
#
#    Total Time Spent on Website  Page Views Per Visit  ...  \
# ...

# %%
# Checking the dimensions of the dataframe

# %%
Leads_data_df.shape
# Out:
# (9240, 37)

# %%
# Checking number of features and their datatypes in the dataframe

# %%
Leads_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9240 entries, 0 to 9239
# Data columns (total 37 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Prospect ID                                    9240 non-null   object
#  1   Lead Number                                    9240 non-null   int64
#  2   Lead Origin                                    9240 non-null   object
#  3   Lead Source                                    9204 non-null   object
#  4   Do Not Email                                   9240 non-null   object
#  5   Do Not Call                                    9240 non-null   object
#  6   Converted                                      9240 non-null   int64
#  7   TotalVisits                                    9103 non-null   float64
#  8   Total Time Spent on Website                    9240 non-null   int64
# ...

# %%
# Checking the various statistics of numeric variables of dataframe

# %%
Leads_data_df.describe()
# Out:
#          Lead Number    Converted  TotalVisits  Total Time Spent on Website  \
# count    9240.000000  9240.000000  9103.000000                  9240.000000
# mean   617188.435606     0.385390     3.445238                   487.698268
# std     23405.995698     0.486714     4.854853                   548.021466
# min    579533.000000     0.000000     0.000000                     0.000000
# 25%    596484.500000     0.000000     1.000000                    12.000000
# 50%    615479.000000     0.000000     3.000000                   248.000000
# 75%    637387.250000     1.000000     5.000000                   936.000000
# max    660737.000000     1.000000   251.000000                  2272.000000
#
#        Page Views Per Visit  Asymmetrique Activity Score  \
# count           9103.000000                  5022.000000
# mean               2.362820                    14.306252
# std                2.161418                     1.386694
# ...

# %%
# Checking the data dictionary

# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
dict_data_df = pd.read_excel("Leads Data Dictionary.xlsx")

# %%
dict_data_df.head(100)
# Out:
#     Unnamed: 0                                        Unnamed: 1  \
# 0          NaN                                               NaN
# 1          NaN                                         Variables
# 2          NaN                                       Prospect ID
# 3          NaN                                       Lead Number
# 4          NaN                                       Lead Origin
# 5          NaN                                       Lead Source
# 6          NaN                                      Do Not Email
# 7          NaN                                       Do Not Call
# 8          NaN                                         Converted
# 9          NaN                                       TotalVisits
# 10         NaN                       Total Time Spent on Website
# 11         NaN                              Page Views Per Visit
# 12         NaN                                     Last Activity
# ...

# %% [markdown]
# Inferences:
# -------------------------
#         ----> Leads_data_df contains 37 features
#         ----> 4 features are of float64 datatype
#         ----> 3 features are of int64 datatype
#         ----> 30 features are of object datatype

# %% [markdown]
# ✍🏻<span style = 'color:darkslateblue'>_**Step-2: Data Pre-processing**_

# %%
# Again checking the dataframe
Leads_data_df.info("all")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9240 entries, 0 to 9239
# Data columns (total 37 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Prospect ID                                    9240 non-null   object
#  1   Lead Number                                    9240 non-null   int64
#  2   Lead Origin                                    9240 non-null   object
#  3   Lead Source                                    9204 non-null   object
#  4   Do Not Email                                   9240 non-null   object
#  5   Do Not Call                                    9240 non-null   object
#  6   Converted                                      9240 non-null   int64
#  7   TotalVisits                                    9103 non-null   float64
#  8   Total Time Spent on Website                    9240 non-null   int64
# ...

# %%
Leads_data_df.head()
# Out:
#                             Prospect ID  Lead Number              Lead Origin  \
# 0  7927b2df-8bba-4d29-b9a2-b6e0beafe620       660737                      API
# 1  2a272436-5132-4136-86fa-dcc88c88f482       660728                      API
# 2  8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727  Landing Page Submission
# 3  0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719  Landing Page Submission
# 4  3256f628-e534-4826-9d63-4a8b88782852       660681  Landing Page Submission
#
#       Lead Source Do Not Email Do Not Call  Converted  TotalVisits  \
# 0      Olark Chat           No          No          0          0.0
# 1  Organic Search           No          No          0          5.0
# 2  Direct Traffic           No          No          1          2.0
# 3  Direct Traffic           No          No          0          1.0
# 4          Google           No          No          1          2.0
#
#    Total Time Spent on Website  Page Views Per Visit  ...  \
# ...

# %% [markdown]
# <span style = 'color:darkslateblue'>_**1️⃣ Checking for categorical variables**_

# %% [markdown]
# 🎗️<span style = 'color:indigo'>_In this step <span style = 'color:tomato'>**categorical variables** <span style = 'color:indigo'>in the dataframes are checked._

# %%
Leads_data_df.head()
# Out:
#                             Prospect ID  Lead Number              Lead Origin  \
# 0  7927b2df-8bba-4d29-b9a2-b6e0beafe620       660737                      API
# 1  2a272436-5132-4136-86fa-dcc88c88f482       660728                      API
# 2  8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727  Landing Page Submission
# 3  0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719  Landing Page Submission
# 4  3256f628-e534-4826-9d63-4a8b88782852       660681  Landing Page Submission
#
#       Lead Source Do Not Email Do Not Call  Converted  TotalVisits  \
# 0      Olark Chat           No          No          0          0.0
# 1  Organic Search           No          No          0          5.0
# 2  Direct Traffic           No          No          1          2.0
# 3  Direct Traffic           No          No          0          1.0
# 4          Google           No          No          1          2.0
#
#    Total Time Spent on Website  Page Views Per Visit  ...  \
# ...

# %% [markdown]
# <span style = 'color:cadetblue'>**It can be observerd that 30 columns are of categorical type.**

# %% [markdown]
# <span style = 'color:darkslateblue'>_**2️⃣ Checking for necessary information**_

# %%
#checking all the columns
Leads_data_df.columns
# Out:
# Index(['Prospect ID', 'Lead Number', 'Lead Origin', 'Lead Source',
#        'Do Not Email', 'Do Not Call', 'Converted', 'TotalVisits',
#        'Total Time Spent on Website', 'Page Views Per Visit', 'Last Activity',
#        'Country', 'Specialization', 'How did you hear about X Education',
#        'What is your current occupation',
#        'What matters most to you in choosing a course', 'Search', 'Magazine',
#        'Newspaper Article', 'X Education Forums', 'Newspaper',
#        'Digital Advertisement', 'Through Recommendations',
#        'Receive More Updates About Our Courses', 'Tags', 'Lead Quality',
#        'Update me on Supply Chain Content', 'Get updates on DM Content',
#        'Lead Profile', 'City', 'Asymmetrique Activity Index',
#        'Asymmetrique Profile Index', 'Asymmetrique Activity Score',
#        'Asymmetrique Profile Score',
#        'I agree to pay the amount through cheque',
#        'A free copy of Mastering The Interview', 'Last Notable Activity'],
# ...

# %%
# checking for null values in the dataframe
Leads_data_df.isnull().sum()
# Out:
# Prospect ID                                         0
# Lead Number                                         0
# Lead Origin                                         0
# Lead Source                                        36
# Do Not Email                                        0
# Do Not Call                                         0
# Converted                                           0
# TotalVisits                                       137
# Total Time Spent on Website                         0
# Page Views Per Visit                              137
# Last Activity                                     103
# Country                                          2461
# Specialization                                   1438
# How did you hear about X Education               2207
# What is your current occupation                  2690
# What matters most to you in choosing a course    2709
# Search                                              0
# ...

# %% [markdown]
# <span style = 'color:darkcyan'>_**As previously observed the columns there are some values where just select is present. This is because the students have not filled that particular and so it can be considered as null as well.**_

# %%
# Converting 'Select' values to NaN.
Leads_data_df = Leads_data_df.replace('Select', np.NaN)

# %%
# Again checking for null values in the dataframe
Leads_data_df.isnull().sum()
# Out:
# Prospect ID                                         0
# Lead Number                                         0
# Lead Origin                                         0
# Lead Source                                        36
# Do Not Email                                        0
# Do Not Call                                         0
# Converted                                           0
# TotalVisits                                       137
# Total Time Spent on Website                         0
# Page Views Per Visit                              137
# Last Activity                                     103
# Country                                          2461
# Specialization                                   3380
# How did you hear about X Education               7250
# What is your current occupation                  2690
# What matters most to you in choosing a course    2709
# Search                                              0
# ...

# %%
# calculating percentage of null values in each column
round(100*(Leads_data_df.isnull().sum()/len(Leads_data_df.index)), 2)
# Out:
# Prospect ID                                       0.00
# Lead Number                                       0.00
# Lead Origin                                       0.00
# Lead Source                                       0.39
# Do Not Email                                      0.00
# Do Not Call                                       0.00
# Converted                                         0.00
# TotalVisits                                       1.48
# Total Time Spent on Website                       0.00
# Page Views Per Visit                              1.48
# Last Activity                                     1.11
# Country                                          26.63
# Specialization                                   36.58
# How did you hear about X Education               78.46
# What is your current occupation                  29.11
# What matters most to you in choosing a course    29.32
# Search                                            0.00
# ...

# %%
null_data = pd.DataFrame((Leads_data_df.isnull().sum())*100/Leads_data_df.shape[0]).reset_index()
null_data.columns = ['Column Name', 'Null Values Percentage']
fig = plt.figure(figsize=(18,6))
ax = sns.pointplot(x="Column Name",y="Null Values Percentage",data=null_data,color='seagreen')
plt.xticks(rotation =90,fontsize = 15)
ax.axhline(70, ls='--',color='red')
plt.title("Percentage of Missing values in application data")
plt.ylabel("Null Values PERCENTAGE")
plt.xlabel("COLUMNS")
plt.show()

# %% [markdown]
# <span style = 'color:darkcyan'>_**As we can observe that there are only 2 features crossing the 70% mark in null value percentage so we can drop those two.**_

# %%
Leads_data_df = Leads_data_df.drop(Leads_data_df.loc[:,list(round(100*(Leads_data_df.isnull().sum()/len(Leads_data_df.index)), 2)>70)].columns, 1)

# %%
# Again checking for null values
null_data = pd.DataFrame((Leads_data_df.isnull().sum())*100/Leads_data_df.shape[0]).reset_index()
null_data.columns = ['Column Name', 'Null Values Percentage']
fig = plt.figure(figsize=(18,6))
ax = sns.pointplot(x="Column Name",y="Null Values Percentage",data=null_data,color='seagreen')
plt.xticks(rotation =90,fontsize = 15)
ax.axhline(70, ls='--',color='red')
plt.title("Percentage of Missing values in application data")
plt.ylabel("Null Values PERCENTAGE")
plt.xlabel("COLUMNS")
plt.show()

# %% [markdown]
# <span style = 'color:darkcyan'>_**As previously observed the columns there are some values which are yet to be calculated under the null values. But for that we have to check the data for each feature.**_

# %%
#Looking at Tags feature
plt.figure(figsize=(20,10))
sns.countplot(Leads_data_df['Tags'])
plt.xticks(rotation = 90,fontsize = 15)

plt.show()

# %% [markdown]
# <span style = 'color:darkcyan'>_**As we can observe here that there are two categories wrong number or invalid number which imply the same so we can replace invalid number as well with wrong number.**_

# %%
# replacing "wrong number given" with "invalid number"
Leads_data_df.Tags = Leads_data_df.Tags.replace("wrong number given", "invalid number")

# %%
#Again Looking at Tags feature
plt.figure(figsize=(20,10))
sns.countplot(Leads_data_df['Tags'])
plt.xticks(rotation = 90,fontsize = 15)

plt.show()

# %% [markdown]
# <span style = 'color:darkcyan'>_**We can replace the NaN values with 'Will revert after reading email'.**_

# %%
Leads_data_df['Tags'] = Leads_data_df['Tags'].replace(np.NaN, 'Will revert after reading the email')

# %%
Leads_data_df['Lead Quality'].describe()
# Out:
# count         4473
# unique           5
# top       Might be
# freq          1560
# Name: Lead Quality, dtype: object

# %%
plt.figure(figsize=(10,10))
sns.countplot(Leads_data_df['Lead Quality'])
plt.show()

# %%
Leads_data_df['Lead Quality'].head()
# Out:
# 0    Low in Relevance
# 1                 NaN
# 2            Might be
# 3            Not Sure
# 4            Might be
# Name: Lead Quality, dtype: object

# %% [markdown]
# <span style = 'color:darkcyan'>_**As we can observe here that there are two categories NaN or not sure which imply the same so we can replace NaN as well with not sure.**_

# %%
# replacing "wrong number given" with "invalid number"
Leads_data_df['Lead Quality'] = Leads_data_df['Lead Quality'].replace(np.NaN, "Not Sure")

# %%
# Again checking the Lead Quality
plt.figure(figsize=(10,10))
sns.countplot(Leads_data_df['Lead Quality'])
plt.show()

# %%
#Let us now look at the assymetric parameters.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
fig, axs = plt.subplots(2,2, figsize = (15,15))
plt1 = sns.countplot(Leads_data_df['Asymmetrique Activity Index'], ax = axs[0,0])
plt2 = sns.boxplot(Leads_data_df['Asymmetrique Activity Score'], ax = axs[0,1])
plt3 = sns.countplot(Leads_data_df['Asymmetrique Profile Index'], ax = axs[1,0])
plt4 = sns.boxplot(Leads_data_df['Asymmetrique Profile Score'], ax = axs[1,1])
plt.show()

# %% [markdown]
# <span style = 'color:darkcyan'>_**Here we can observe that there are too many variations in the data so nothing can be imputed in this zone. So the wise decision would be to drop the missing values above the threshold of 45%**_

# %%
Leads_data_df = Leads_data_df.drop(['Asymmetrique Activity Index','Asymmetrique Activity Score','Asymmetrique Profile Index','Asymmetrique Profile Score'],1)

# %%
round(100*(Leads_data_df.isnull().sum()/len(Leads_data_df.index)), 2)
# Out:
# Prospect ID                                       0.00
# Lead Number                                       0.00
# Lead Origin                                       0.00
# Lead Source                                       0.39
# Do Not Email                                      0.00
# Do Not Call                                       0.00
# Converted                                         0.00
# TotalVisits                                       1.48
# Total Time Spent on Website                       0.00
# Page Views Per Visit                              1.48
# Last Activity                                     1.11
# Country                                          26.63
# Specialization                                   36.58
# What is your current occupation                  29.11
# What matters most to you in choosing a course    29.32
# Search                                            0.00
# Magazine                                          0.00
# ...

# %%
# Let's look at the country data
Leads_data_df.City.describe()
# Out:
# count       5571
# unique         6
# top       Mumbai
# freq        3222
# Name: City, dtype: object

# %%
sns.countplot(Leads_data_df.City)
plt.xticks(rotation = 90,fontsize = 15)

plt.show()

# %% [markdown]
# <span style = 'color:darkcyan'>_**Here we can observe that there are more than 60% of data relating to the Mumbai so we can impute this value wherever city data is missing**_

# %%
Leads_data_df['City'] = Leads_data_df['City'].replace(np.NaN, 'Mumbai')

# %%
round(100*(Leads_data_df.isnull().sum()/len(Leads_data_df.index)), 2)
# Out:
# Prospect ID                                       0.00
# Lead Number                                       0.00
# Lead Origin                                       0.00
# Lead Source                                       0.39
# Do Not Email                                      0.00
# Do Not Call                                       0.00
# Converted                                         0.00
# TotalVisits                                       1.48
# Total Time Spent on Website                       0.00
# Page Views Per Visit                              1.48
# Last Activity                                     1.11
# Country                                          26.63
# Specialization                                   36.58
# What is your current occupation                  29.11
# What matters most to you in choosing a course    29.32
# Search                                            0.00
# Magazine                                          0.00
# ...

# %%
# Let's now look at the next parameter Specialization
Leads_data_df.Specialization.describe()
# Out:
# count                   5860
# unique                    18
# top       Finance Management
# freq                     976
# Name: Specialization, dtype: object

# %%
plt.figure(figsize=(12,15))
sns.countplot(Leads_data_df.Specialization)
plt.xticks(rotation = 90,fontsize = 15)

plt.show()

# %% [markdown]
# <span style = 'color:darkcyan'>_**Here we can observe that most of the possible Specializations are mentioned and wherever there are missing values we can impute it with a unknown or others category.**_

# %%
Leads_data_df['Specialization'] = Leads_data_df['Specialization'].replace(np.NaN, 'Others')

# %%
round(100*(Leads_data_df.isnull().sum()/len(Leads_data_df.index)), 2)
# Out:
# Prospect ID                                       0.00
# Lead Number                                       0.00
# Lead Origin                                       0.00
# Lead Source                                       0.39
# Do Not Email                                      0.00
# Do Not Call                                       0.00
# Converted                                         0.00
# TotalVisits                                       1.48
# Total Time Spent on Website                       0.00
# Page Views Per Visit                              1.48
# Last Activity                                     1.11
# Country                                          26.63
# Specialization                                    0.00
# What is your current occupation                  29.11
# What matters most to you in choosing a course    29.32
# Search                                            0.00
# Magazine                                          0.00
# ...

# %%
# Let's look at the next feature 'What matters most to you in choosing a course'

# %%
Leads_data_df['What matters most to you in choosing a course'].describe()
# Out:
# count                        6531
# unique                          3
# top       Better Career Prospects
# freq                         6528
# Name: What matters most to you in choosing a course, dtype: object

# %%
Leads_data_df['What matters most to you in choosing a course'].head()
# Out:
# 0    Better Career Prospects
# 1    Better Career Prospects
# 2    Better Career Prospects
# 3    Better Career Prospects
# 4    Better Career Prospects
# Name: What matters most to you in choosing a course, dtype: object

# %%
Leads_data_df['What matters most to you in choosing a course'].isnull().sum()
# Out:
# 2709

# %% [markdown]
# <span style = 'color:darkcyan'>_**Here we can observe that there is a rating scale used for the better career prospects from 0 to 4. But in data dictionary we can observe it is a measure used to know the main aim of joining the course. So for the NaN values also we will impute it with the Better Career Prospects entry only.**_

# %%
Leads_data_df['What matters most to you in choosing a course'] = Leads_data_df['What matters most to you in choosing a course'].replace(np.nan, 'Better Career Prospects')

# %%
round(100*(Leads_data_df.isnull().sum()/len(Leads_data_df.index)), 2)
# Out:
# Prospect ID                                       0.00
# Lead Number                                       0.00
# Lead Origin                                       0.00
# Lead Source                                       0.39
# Do Not Email                                      0.00
# Do Not Call                                       0.00
# Converted                                         0.00
# TotalVisits                                       1.48
# Total Time Spent on Website                       0.00
# Page Views Per Visit                              1.48
# Last Activity                                     1.11
# Country                                          26.63
# Specialization                                    0.00
# What is your current occupation                  29.11
# What matters most to you in choosing a course     0.00
# Search                                            0.00
# Magazine                                          0.00
# ...

# %%
# Let's now look at the occupation parameter

# %%
Leads_data_df['What is your current occupation'].describe()
# Out:
# count           6550
# unique             6
# top       Unemployed
# freq            5600
# Name: What is your current occupation, dtype: object

# %%
plt.figure(figsize=(10,10))
sns.countplot(Leads_data_df['What is your current occupation'])
plt.xticks(rotation = 90,fontsize = 15)

plt.show()

# %% [markdown]
# <span style = 'color:darkcyan'>_**Here we can observe that close to 96% entries are of Unemployed. So we can impute the Nan entries here as Unemployed category.**_

# %%
Leads_data_df['What is your current occupation'] = Leads_data_df['What is your current occupation'].replace(np.nan, 'Unemployed')

# %%
round(100*(Leads_data_df.isnull().sum()/len(Leads_data_df.index)), 2)
# Out:
# Prospect ID                                       0.00
# Lead Number                                       0.00
# Lead Origin                                       0.00
# Lead Source                                       0.39
# Do Not Email                                      0.00
# Do Not Call                                       0.00
# Converted                                         0.00
# TotalVisits                                       1.48
# Total Time Spent on Website                       0.00
# Page Views Per Visit                              1.48
# Last Activity                                     1.11
# Country                                          26.63
# Specialization                                    0.00
# What is your current occupation                   0.00
# What matters most to you in choosing a course     0.00
# Search                                            0.00
# Magazine                                          0.00
# ...

# %%
# Looking at the country data

# %%
plt.figure(figsize=(15,15))
sns.countplot(Leads_data_df['Country'])
plt.xticks(rotation = 90,fontsize = 15)

plt.show()

# %% [markdown]
# <span style = 'color:darkcyan'>_**Here we can observe that most of the entries are of India. So we can impute all NaN with India.**_

# %%
Leads_data_df['Country'] = Leads_data_df['Country'].replace(np.nan, 'India')

# %%
round(100*(Leads_data_df.isnull().sum()/len(Leads_data_df.index)), 2)
# Out:
# Prospect ID                                      0.00
# Lead Number                                      0.00
# Lead Origin                                      0.00
# Lead Source                                      0.39
# Do Not Email                                     0.00
# Do Not Call                                      0.00
# Converted                                        0.00
# TotalVisits                                      1.48
# Total Time Spent on Website                      0.00
# Page Views Per Visit                             1.48
# Last Activity                                    1.11
# Country                                          0.00
# Specialization                                   0.00
# What is your current occupation                  0.00
# What matters most to you in choosing a course    0.00
# Search                                           0.00
# Magazine                                         0.00
# ...

# %% [markdown]
# <span style = 'color:darkcyan'>_**Here we can observe that now we have entries of data with either less than 1.5% NaN or 0 NaN entries. So we can just drop them.**_

# %%
Leads_data_df.dropna(inplace = True)

# %%
round(100*(Leads_data_df.isnull().sum()/len(Leads_data_df.index)), 2)
# Out:
# Prospect ID                                      0.0
# Lead Number                                      0.0
# Lead Origin                                      0.0
# Lead Source                                      0.0
# Do Not Email                                     0.0
# Do Not Call                                      0.0
# Converted                                        0.0
# TotalVisits                                      0.0
# Total Time Spent on Website                      0.0
# Page Views Per Visit                             0.0
# Last Activity                                    0.0
# Country                                          0.0
# Specialization                                   0.0
# What is your current occupation                  0.0
# What matters most to you in choosing a course    0.0
# Search                                           0.0
# Magazine                                         0.0
# Newspaper Article                                0.0
# ...

# %% [markdown]
# ✍🏻<span style = 'color:darkslateblue'>_**Step-3: Exploratory Data Analysis**_

# %% [markdown]
# 🎗️<span style = 'color:indigo'>_In this step <span style = 'color:tomato'>**data visualisation** <span style = 'color:indigo'>in the dataframe is done for a better understanding._
